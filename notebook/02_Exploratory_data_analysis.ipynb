# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df = pd.read_csv("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["tenure"], bins = 30, kde = True)
plt.title("Distribution of Tenure")
plt.show()


plt.figure(figsize = (8, 3))
sns.boxplot(x = df["tenure"])
plt.show()

plt.figure(figsize =(8, 5))
sns.histplot(df["MonthlyCharges"], bins =30, kde = True)
plt.title("Distribution of MonthlyCharges")
plt.show()

plt.figure(figsize=(8, 4))
sns.boxplot(x = df["MonthlyCharges"])
plt.show()

# %%
sns.countplot(x= "Contract", hue="Churn", data = df)
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %%
plt.figure(figsize= (24, 10))
sns.countplot(x= "InternetService", hue="Churn", data = df)
sns.countplot(x= "OnlineSecurity", hue="Churn", data = df)
sns.countplot(x= "TechSupport", hue="Churn", data = df)
sns.countplot(x= "PaymentMethod", hue="Churn", data = df)
sns.countplot(x= "SeniorCitizen", hue="Churn", data = df)
sns.countplot(x= "Partner", hue="Churn", data = df)
sns.countplot(x= "Dependents", hue="Churn", data = df)
plt.show()

# %%
sns.boxplot(x="Churn", y="tenure", data =df)
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %%
sns.boxplot(x="Churn", y="MonthlyCharges", data =df)
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")

# %%
plt.figure(figsize = (8, 6))
sns.boxplot(x="Churn", y="TotalCharges", data = df)
plt.show()

# %% [markdown]
# ### ⭐ Business Insights You Should Write in Markdown
#
# Here are examples of the kind of observations I expect:
#
# 1. Customers with month-to-month contracts churn significantly more than those with long-term contracts.
# 2. Customers with shorter tenure are more likely to churn.
# 3. Higher monthly charges are associated with higher churn rates.
# 4. Long-term customers tend to remain loyal.
# 5. Two-year contract customers have the lowest churn rate.
# 6. Month-to-month customers represent the highest-risk customer segment.
# 7. Most customers fall within the ₹70–100 monthly charge range.
# 8. The tenure distribution suggests customers either leave early or remain for many years.
