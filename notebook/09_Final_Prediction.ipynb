# %% [markdown]
# # Final Prediction
#
# In this notebook, we load the trained machine learning pipeline and use it to predict whether a new customer is likely to churn.
#
# This simulates how the model will be used in a real-world application.

# %%
import pandas as pd
import joblib

model = joblib.load("../artifacts/final_model.pkl")

df = pd.read_csv("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")

X = df.drop("Churn", axis=1)

print(X.columns.tolist())
# Out:
# ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges']

# %%
new_customer = pd.DataFrame({
    "gender": [0],                  # Female
    "SeniorCitizen": [0],
    "Partner": [1],                 # Yes
    "Dependents": [0],              # No
    "tenure": [12],
    "PhoneService": [1],            # Yes
    "MultipleLines": ["No"],
    "InternetService": ["Fiber optic"],
    "OnlineSecurity": ["No"],
    "OnlineBackup": ["Yes"],
    "DeviceProtection": ["No"],
    "TechSupport": ["No"],
    "StreamingTV": ["Yes"],
    "StreamingMovies": ["Yes"],
    "Contract": ["Month-to-month"],
    "PaperlessBilling": [1],        # Yes
    "PaymentMethod": ["Electronic check"],
    "MonthlyCharges": [75.25],
    "TotalCharges": [850.40]
})

prediction = model.predict(new_customer)

prediction

probability = model.predict_proba(new_customer)

probability

if prediction[0] == 1:
    print("⚠️ Customer is likely to Churn.")
else:
    print("✅ Customer id likely to Stay")

print(f"Churn Probability: {probability[0][1] * 100:.2f}%")
# Out:
# ⚠️ Customer is likely to Churn.
# Churn Probability: 76.00%
