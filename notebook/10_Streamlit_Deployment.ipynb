# %% [markdown]
# # Streamlit Deployment
#
# ## Customer Retention Intelligence Platform
#
# In this notebook, we deploy the trained machine learning model using Streamlit. The goal is to create an interactive web application where users can enter customer information and receive churn predictions in real time.

# %% [markdown]
# ## Objective
#
# - Deploy the trained machine learning model.
# - Build an interactive user interface.
# - Allow users to enter customer information.
# - Predict customer churn.
# - Display churn probability.

# %% [markdown]
# ## Why Streamlit?
#
# After training the model, the next step is deployment.
#
# Instead of running predictions from a Jupyter Notebook, Streamlit allows us to build an interactive web application.
#
# Benefits:
# - Easy deployment
# - Interactive interface
# - No frontend knowledge required
# - Ideal for ML applications

# %%
import streamlit as st
import joblib
import pandas as pd

model = joblib.load("../artifacts/final_model.pkl")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# The application uses different Streamlit widgets:
#
# - selectbox() for categorical variables
# - number_input() for numerical variables
# - button() for prediction
# - metric() for displaying probability

# %% [markdown]
# Run the application using:
#
# streamlit run app/app.py
